# %% [markdown]
# # 일자 데이터 처리 _LA Bike Sharing Demand

# %% [markdown]
# ### 학습 목표
# - 시간 개념을 지닌 날짜 데이터를 처리하는 법을 익힌다.

# %%
import pandas as pd

# %%
train = pd.read_csv('../Data/train_bike.csv')

# %%
print("train_df_length : ",len(train))
train.head()
# Out:
# train_df_length :  10886
#               datetime  season  holiday  workingday  weather  temp   atemp
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395  \
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
train = pd.read_csv('../Data/train_bike.csv', parse_dates=['datetime'])
# parse_dates --> 'datetime'을 날짜 데이타루 인식해라, 그리고 분석하겠다
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
train['datetime-year'] = train['datetime'].dt.year # dt: 시간 개념 추출 연산자
train['datetime-month'] = train['datetime'].dt.month
train['datetime-day'] = train['datetime'].dt.day
train['datetime-hour'] = train['datetime'].dt.hour
train['datetime-minute'] = train['datetime'].dt.minute
train['datetime-second'] = train['datetime'].dt.second
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395  \
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  datetime-year
# 0        81        0.0       3          13     16           2011  \
# 1        80        0.0       8          32     40           2011
# 2        80        0.0       5          27     32           2011
# 3        75        0.0       3          10     13           2011
# 4        75        0.0       0           1      1           2011
#
#    datetime-month  datetime-day  datetime-hour  datetime-minute
# ...

# %% [markdown]
# - 요일을 자동으로 표시해 주는 기능

# %%
# 요일을 알려주는 함수 --> day_name() 
train['datetime-dayname'] = train['datetime'].dt.day_name()
train
# Out:
#                  datetime  season  holiday  workingday  weather   temp
# 0     2011-01-01 00:00:00       1        0           0        1   9.84  \
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  datetime-year
# ...

# %%
# 사용자 정의 함수 -> 연도-월을 표시해주는 새로운 column. e.g 2011-1

def concat_year_month(date):
    return '{}-{}'.format(date.year,date.month)

concat_year_month(train['datetime'][10885])
# Out:
# '2012-12'

# %%
# apply() --> 간접적용함수
train['datetime-year_month'] = train['datetime'].apply(concat_year_month)
train
# Out:
#                  datetime  season  holiday  workingday  weather   temp
# 0     2011-01-01 00:00:00       1        0           0        1   9.84  \
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  datetime-year
# ...
